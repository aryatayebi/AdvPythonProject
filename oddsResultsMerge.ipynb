# %%
import pandas as pd
import numpy as np

# %%
oddsDf = pd.read_csv('nbaOdds.csv')
resultsDf = pd.read_csv('nbaResults.csv')

oddsDf.drop(columns=['sport','gameState'],inplace=True)


print(oddsDf.shape)
print(resultsDf.shape)
# Out:
# (274, 20)
# (195, 26)

# %%
new_res = resultsDf[pd.isna(resultsDf.awayTeam)==False].copy()
resultsDf = resultsDf[pd.isna(resultsDf.awayTeam)].copy()

# %%
resultsDf.columns
# Out:
# Index(['AwayDiff', 'AwayOutcome', 'AwayTeam', 'Date_Time', 'Game_State',
#        'HomeDiff', 'HomeOutcome', 'HomeTeam', 'Sb_id', 'Score', 'Sport',
#        'Total', '__id__', 'id', 'awayDiff', 'awayOutcome', 'awayTeam',
#        'dateTime', 'gameState', 'homeDiff', 'homeOutcome', 'homeTeam', 'sbId',
#        'score', 'sport', 'total'],
#       dtype='object')

# %%
new_res.drop(columns=['AwayDiff', 'AwayOutcome', 'AwayTeam', 'Date_Time', 'Game_State',
       'HomeDiff', 'HomeOutcome', 'HomeTeam', 'Sb_id', 'Score', 'Sport',
       'Total'],inplace=True)
resultsDf.drop(columns=['awayDiff', 'awayOutcome', 'awayTeam',
       'dateTime', 'gameState', 'homeDiff', 'homeOutcome', 'homeTeam', 'sbId',
       'score', 'sport', 'total'],inplace=True)

# %%
resultsDf.columns
resultsDf.rename(columns = {'AwayDiff':'awayDiff', 'AwayOutcome':'awayOutcome', 'AwayTeam':'awayTeam', 
                            'Date_Time':'dateTime', 'Game_State':'gameState','HomeDiff':'homeDiff', 
                            'HomeOutcome':'homeOutcome', 'HomeTeam':'homeTeam', 'Sb_id':'sbId', 'Score':'score',
                            'Sport':'sport','Total':'total'}, inplace=True)

# %%
oddsDf.rename(columns = {'AwayTeam':'awayTeam', 'Away_Odds':'awayOdds', 'Away_Spread':'awaySpread', 
                         'Away_Spread_Odds':'awaySpreadOdds', 'Book_Odds':'bookOdds', 'Consensus':'consensus', 
                         'Date_Time':'dateTime', 'Game_State':'gameState', 'HomeTeam':'homeTeam', 
                         'Home_Odds':'homeOdds','Home_Spread':'homeSpread', 'Home_Spread_Odds':'homeSpreadOdds',
                         'Over':'over', 'Over_Odds':'overOdds', 'Sb_id':'sbId',
                        'Sport':'sport', 'Under':'under', 'Under_Odds':'underOdds',}, inplace=True)

# %%
resultsDf.shape
# Out:
# (155, 14)

# %%
new_res.shape
# Out:
# (40, 14)

# %%
resultsDf = pd.concat([resultsDf,new_res])

# %%
### basic cleaning
oddsDf.drop(columns=['bookOdds','consensus','homeTeam','awayTeam','sbId','gameState','id','sport'],inplace=True)
resultsDf.drop(columns=['dateTime'],inplace=True)

# %%
oddsDf.head(5)
# Out:
#    awayOdds  awaySpread  awaySpreadOdds             dateTime  homeOdds  \
# 0      -125        -2.5             100  2022-04-02T19:30:00       125
# 1       190         5.5             100  2022-04-13T19:00:00      -190
# 2       205         6.0             100  2022-03-31T19:30:00      -205
# 3       125         2.5             100  2022-03-25T19:30:00      -125
# 4       590        12.0             100  2022-03-13T19:00:00      -590
#
#    homeSpread  homeSpreadOdds   over  overOdds  under  underOdds  \
# 0         2.5             100  241.0       100  241.0        100
# 1        -5.5             100  235.5       100  235.5        100
# 2        -6.0             100  230.0       100  230.0        100
# 3        -2.5             100  221.5       100  221.5        100
# 4       -12.0             100  237.0       100  237.0        100
#
#           __id__
# 0   ATLBKN422022
# 1  ATLCHA4132022
# 2  ATLCLE3312022
# 3   ATLGS3252022
# 4  ATLIND3132022

# %%
nbaData = resultsDf.merge(oddsDf, on='__id__')

# %%
nbaData.to_csv('allNbaData.csv')

# %%
nbaData
# Out:
#      awayDiff awayOutcome               awayTeam gameState  homeDiff  \
# 0       -11.0           L  Golden State Warriors     Final      11.0
# 1        -3.0           L         Indiana Pacers     Final       3.0
# 2        -6.0           L   Los Angeles Clippers     Final       6.0
# 3       -15.0           L      Memphis Grizzlies     Final      15.0
# 4         5.0           W   New Orleans Pelicans     Final      -5.0
# ..        ...         ...                    ...       ...       ...
# 161     -24.0           L          Atlanta Hawks     Final      24.0
# 162      -7.0           L          Chicago Bulls     Final       7.0
# 163     -20.0           L        Toronto Raptors     Final      20.0
# 164     -15.0           L        Toronto Raptors     Final      15.0
# 165     -11.0           L   New Orleans Pelicans     Final      11.0
#
#     homeOutcome            homeTeam     sbId    score sport  ...  awaySpread  \
# 0             W       Atlanta Hawks  17793.0  121-110   NBA  ...         2.5
# 1             W       Atlanta Hawks  17707.0  131-128   NBA  ...        12.0
# 2             W       Atlanta Hawks  17687.0  112-106   NBA  ...         7.5
# 3             W       Atlanta Hawks  17738.0  120-105   NBA  ...        -5.5
# 4             L       Atlanta Hawks  17755.0  112-117   NBA  ...         3.5
# ..          ...                 ...      ...      ...   ...  ...         ...
# 161           W          Miami Heat  18057.0   115-91   NBA  ...         7.0
# 162           W     Milwaukee Bucks  18016.0    93-86   NBA  ...        10.5
# 163           W  Philadelphia 76ers  18014.0  131-111   NBA  ...         4.5
# 164           W  Philadelphia 76ers  18019.0   112-97   NBA  ...         7.0
# 165           W        Phoenix Suns  18058.0   110-99   NBA  ...        10.5
#
#     awaySpreadOdds             dateTime  homeOdds  homeSpread  homeSpreadOdds  \
# 0              100  2022-03-25T19:30:00      -125        -2.5             100
# 1              100  2022-03-13T19:00:00      -590       -12.0             100
# 2              100  2022-03-11T19:30:00      -250        -7.5             100
# 3              100  2022-03-18T19:30:00       185         5.5             100
# 4              100  2022-03-20T18:00:00      -145        -3.5             100
# ..             ...                  ...       ...         ...             ...
# 161            100  2022-04-17T13:00:00      -240        -7.0             100
# 162            100  2022-04-17T18:30:00      -450       -10.5             100
# 163            100  2022-04-16T18:00:00      -170        -4.5             100
# 164            100  2022-04-18T19:30:00      -245        -7.0             100
# 165            100  2022-04-17T21:00:00      -445       -10.5             100
#
#       over  overOdds  under  underOdds
# 0    221.5       100  221.5        100
# 1    237.0       100  237.0        100
# 2    226.5       100  226.5        100
# 3    237.5       100  237.5        100
# 4    233.0       100  233.0        100
# ..     ...       ...    ...        ...
# 161  219.5       100  219.5        100
# 162  230.0       100  230.0        100
# 163  216.0       100  216.0        100
# 164  218.0       100  218.0        100
# 165  224.0       100  224.0        100
#
# [166 rows x 24 columns]
